# %% [markdown]
# # Open this notebook from google drive
# Go to "Edit" -> "Notebook settings" and enable GPU

# %%
# !nvidia-smi
# Out:
# Tue Aug 25 18:19:04 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.57       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   66C    P8    11W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# **Connect and authorize google drive with google colab**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
pwd
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd gdrive/My\ Drive/spectrum_detector_v1
ls
# Out:
# /content/gdrive/My Drive/spectrum_detector_v1
# batch_detector.ipynb  EEG		     saved_models
# batch_train.ipynb     generate_images_v2.py  saved_models2
# checkpoints	      logs		     saved_models3
# detector.ipynb	      mat		     saved_models_40epochs
# detector_subj.py      mat2		     train_subj.py
# detector_train.ipynb  mat3		     utils.py
# DL_trainset	      __pycache__

# %% [markdown]
# # Start my python code here

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
print ('tf:', tf.__version__)
import time
from numpy import save, load
from generate_images_v2 import prepare_one_dataset, plotbars, xloc2binaryvec

# sklearn for PR and ROC curves
from sklearn.metrics import precision_recall_curve, average_precision_score
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.metrics import roc_curve, auc, RocCurveDisplay
from utils import normalize_matrix_1, plot1bar
from utils import plot_loss, plot_metrics, shuffle_trainset
from scipy.io import loadmat, savemat
# Out:
# tf: 2.3.0

# %%
from train_subj import train_subj

# %%
# choose the path for saving 
save_dir = os.path.join(os.getcwd(), 'saved_models_fullASSR')
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)

# %%
subjs = ['s21', 's22', 's24', 's25', 's28', 's30', 's31', 's33', 's34', 's38'] # day 1 for train
#subjs = ['s23', 's27', 's26', 's29', 's37', 's36', 's32', 's35', 's39', 's40'] # day 2 for test

#dev_set =  'AVG_5_100' # full dev set - 'saved_models_40epochs'
dev_set =  'AVG_50_100' # dev set - 'saved_models_fullASSR'
for subj in subjs:
  print(subj + ' ==============================================================')
  train_subj(subj, save_dir, N_epoch = 40, dev_set=dev_set)
# Out:
# s21 ==============================================================
# data1_dev: (96, 60, 120)
# (100, 60, 120)
# (100, 60, 120)
# (100, 60, 120)
# (100, 60, 120)
# (100, 60, 120)
# dev_set:  (50, 60, 120)
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 60, 120, 1)]      0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 60, 120, 1)        0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 60, 120, 8)        80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 60, 120, 8)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 60, 120, 8)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 60, 120, 4)        292
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 60, 120, 4)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 60, 120, 4)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 28800)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              29492224
# _________________________________________________________________
# dense_1 (Dense)              (None, 120)               123000
# =================================================================
# Total params: 29,615,596
# Trainable params: 29,615,596
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/40
#    1/1563 [..............................] - ETA: 1s - loss: 0.7091 - accuracy: 0.5042 - precision: 0.1509 - recall: 0.5404 - auc: 0.1454WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#    2/1563 [..............................] - ETA: 13:00 - loss: 0.7833 - accuracy: 0.6812 - precision: 0.1509 - recall: 0.2702 - auc: 0.1433WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0286s vs `on_train_batch_end` time: 0.9698s). Check your callbacks.
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.3616 - accuracy: 0.8729 - precision: 0.7721 - recall: 0.1456 - auc: 0.3920
# Epoch 00001: val_auc improved from -inf to 0.49945, saving model to checkpoints/my_ckpt
# 1563/1563 [==============================] - 28s 18ms/step - loss: 0.3616 - accuracy: 0.8729 - precision: 0.7721 - recall: 0.1457 - auc: 0.3921 - val_loss: 0.4018 - val_accuracy: 0.8822 - val_precision: 0.6493 - val_recall: 0.3659 - val_auc: 0.4994
# Epoch 2/40
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2892 - accuracy: 0.9039 - precision: 0.8823 - recall: 0.3714 - auc: 0.6362
# Epoch 00002: val_auc improved from 0.49945 to 0.62729, saving model to checkpoints/my_ckpt
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.2892 - accuracy: 0.9039 - precision: 0.8823 - recall: 0.3715 - auc: 0.6362 - val_loss: 0.3420 - val_accuracy: 0.9030 - val_precision: 0.7509 - val_recall: 0.4718 - val_auc: 0.6273
# Epoch 3/40
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.2490 - accuracy: 0.9201 - precision: 0.8800 - recall: 0.5049 - auc: 0.7249
# Epoch 00003: val_auc improved from 0.62729 to 0.67766, saving model to checkpoints/my_ckpt
# 1563/1563 [==============================] - 26s 17ms/step - loss: 0.2490 - accuracy: 0.9201 - precision: 0.8800 - recall: 0.5049 - auc: 0.7249 - val_loss: 0.3304 - val_accuracy: 0.9253 - val_precision: 0.9136 - val_recall: 0.5224 - val_auc: 0.6777
# Epoch 4/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2285 - accuracy: 0.9270 - precision: 0.8778 - recall: 0.5630 - auc: 0.7630
# Epoch 00004: val_auc did not improve from 0.67766
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.2285 - accuracy: 0.9270 - precision: 0.8778 - recall: 0.5630 - auc: 0.7630 - val_loss: 0.3420 - val_accuracy: 0.9165 - val_precision: 0.8156 - val_recall: 0.5306 - val_auc: 0.6571
# Epoch 5/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2179 - accuracy: 0.9298 - precision: 0.8764 - recall: 0.5876 - auc: 0.7806
# Epoch 00005: val_auc did not improve from 0.67766
# 1563/1563 [==============================] - 24s 16ms/step - loss: 0.2179 - accuracy: 0.9298 - precision: 0.8764 - recall: 0.5876 - auc: 0.7806 - val_loss: 0.3380 - val_accuracy: 0.9195 - val_precision: 0.8784 - val_recall: 0.5012 - val_auc: 0.6354
# Epoch 6/40
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.2097 - accuracy: 0.9316 - precision: 0.8738 - recall: 0.6046 - auc: 0.7934
# Epoch 00006: val_auc improved from 0.67766 to 0.70388, saving model to checkpoints/my_ckpt
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.2097 - accuracy: 0.9316 - precision: 0.8738 - recall: 0.6046 - auc: 0.7934 - val_loss: 0.3036 - val_accuracy: 0.9268 - val_precision: 0.9237 - val_recall: 0.5271 - val_auc: 0.7039
# Epoch 7/40
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.2026 - accuracy: 0.9331 - precision: 0.8716 - recall: 0.6188 - auc: 0.8042
# Epoch 00007: val_auc did not improve from 0.70388
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.2026 - accuracy: 0.9331 - precision: 0.8716 - recall: 0.6187 - auc: 0.8042 - val_loss: 0.3028 - val_accuracy: 0.9233 - val_precision: 0.8764 - val_recall: 0.5341 - val_auc: 0.6799
# Epoch 8/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1967 - accuracy: 0.9343 - precision: 0.8706 - recall: 0.6302 - auc: 0.8131
# Epoch 00008: val_auc did not improve from 0.70388
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.1967 - accuracy: 0.9343 - precision: 0.8706 - recall: 0.6302 - auc: 0.8131 - val_loss: 0.3400 - val_accuracy: 0.9045 - val_precision: 0.7560 - val_recall: 0.4812 - val_auc: 0.6256
# Epoch 9/40
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.1916 - accuracy: 0.9354 - precision: 0.8696 - recall: 0.6402 - auc: 0.8206
# Epoch 00009: val_auc did not improve from 0.70388
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.1916 - accuracy: 0.9354 - precision: 0.8696 - recall: 0.6401 - auc: 0.8206 - val_loss: 0.3136 - val_accuracy: 0.9118 - val_precision: 0.7801 - val_recall: 0.5259 - val_auc: 0.6647
# Epoch 10/40
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.1867 - accuracy: 0.9365 - precision: 0.8687 - recall: 0.6498 - auc: 0.8277
# Epoch 00010: val_auc did not improve from 0.70388
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.1868 - accuracy: 0.9365 - precision: 0.8687 - recall: 0.6498 - auc: 0.8277 - val_loss: 0.3027 - val_accuracy: 0.9192 - val_precision: 0.8078 - val_recall: 0.5635 - val_auc: 0.7011
# Epoch 11/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1829 - accuracy: 0.9373 - precision: 0.8678 - recall: 0.6571 - auc: 0.8331
# Epoch 00011: val_auc did not improve from 0.70388
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.1829 - accuracy: 0.9373 - precision: 0.8678 - recall: 0.6571 - auc: 0.8331 - val_loss: 0.3087 - val_accuracy: 0.9075 - val_precision: 0.7438 - val_recall: 0.5294 - val_auc: 0.6826
# Epoch 12/40
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.1789 - accuracy: 0.9383 - precision: 0.8680 - recall: 0.6656 - auc: 0.8389
# Epoch 00012: val_auc did not improve from 0.70388
# 1563/1563 [==============================] - 24s 16ms/step - loss: 0.1789 - accuracy: 0.9383 - precision: 0.8680 - recall: 0.6655 - auc: 0.8389 - val_loss: 0.3440 - val_accuracy: 0.9013 - val_precision: 0.7022 - val_recall: 0.5271 - val_auc: 0.6637
# Epoch 13/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1756 - accuracy: 0.9390 - precision: 0.8677 - recall: 0.6719 - auc: 0.8435
# Epoch 00013: val_auc did not improve from 0.70388
# 1563/1563 [==============================] - 24s 16ms/step - loss: 0.1756 - accuracy: 0.9390 - precision: 0.8677 - recall: 0.6719 - auc: 0.8435 - val_loss: 0.2946 - val_accuracy: 0.9070 - val_precision: 0.7274 - val_recall: 0.5494 - val_auc: 0.6937
# Epoch 14/40
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.1721 - accuracy: 0.9399 - precision: 0.8681 - recall: 0.6789 - auc: 0.8484
# Epoch 00014: val_auc did not improve from 0.70388
# 1563/1563 [==============================] - 24s 16ms/step - loss: 0.1721 - accuracy: 0.9399 - precision: 0.8681 - recall: 0.6789 - auc: 0.8484 - val_loss: 0.3153 - val_accuracy: 0.9112 - val_precision: 0.7450 - val_recall: 0.5671 - val_auc: 0.6998
# Epoch 15/40
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.1699 - accuracy: 0.9404 - precision: 0.8680 - recall: 0.6835 - auc: 0.8515
# Epoch 00015: val_auc did not improve from 0.70388
# 1563/1563 [==============================] - 24s 16ms/step - loss: 0.1699 - accuracy: 0.9404 - precision: 0.8680 - recall: 0.6835 - auc: 0.8515 - val_loss: 0.3044 - val_accuracy: 0.9098 - val_precision: 0.7425 - val_recall: 0.5565 - val_auc: 0.6988
# Epoch 16/40
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.1674 - accuracy: 0.9411 - precision: 0.8684 - recall: 0.6884 - auc: 0.8550
# Epoch 00016: val_auc did not improve from 0.70388
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.1674 - accuracy: 0.9411 - precision: 0.8684 - recall: 0.6884 - auc: 0.8550 - val_loss: 0.2957 - val_accuracy: 0.9062 - val_precision: 0.7232 - val_recall: 0.5471 - val_auc: 0.6866
# Epoch 17/40
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.1650 - accuracy: 0.9417 - precision: 0.8690 - recall: 0.6930 - auc: 0.8583
# Epoch 00017: val_auc improved from 0.70388 to 0.72965, saving model to checkpoints/my_ckpt
# 1563/1563 [==============================] - 26s 16ms/step - loss: 0.1650 - accuracy: 0.9417 - precision: 0.8690 - recall: 0.6930 - auc: 0.8583 - val_loss: 0.2779 - val_accuracy: 0.9207 - val_precision: 0.8224 - val_recall: 0.5612 - val_auc: 0.7297
# Epoch 18/40
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.1628 - accuracy: 0.9423 - precision: 0.8696 - recall: 0.6975 - auc: 0.8613
# Epoch 00018: val_auc did not improve from 0.72965
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.1628 - accuracy: 0.9423 - precision: 0.8696 - recall: 0.6975 - auc: 0.8613 - val_loss: 0.3255 - val_accuracy: 0.9022 - val_precision: 0.7084 - val_recall: 0.5259 - val_auc: 0.6518
# Epoch 19/40
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.1612 - accuracy: 0.9427 - precision: 0.8697 - recall: 0.7009 - auc: 0.8636
# Epoch 00019: val_auc did not improve from 0.72965
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.1612 - accuracy: 0.9427 - precision: 0.8697 - recall: 0.7009 - auc: 0.8636 - val_loss: 0.3295 - val_accuracy: 0.9050 - val_precision: 0.7194 - val_recall: 0.5400 - val_auc: 0.6814
# Epoch 20/40
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.1594 - accuracy: 0.9431 - precision: 0.8693 - recall: 0.7038 - auc: 0.8658
# Epoch 00020: val_auc did not improve from 0.72965
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.1594 - accuracy: 0.9431 - precision: 0.8693 - recall: 0.7038 - auc: 0.8658 - val_loss: 0.3248 - val_accuracy: 0.9010 - val_precision: 0.6910 - val_recall: 0.5447 - val_auc: 0.6815
# Epoch 21/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1576 - accuracy: 0.9435 - precision: 0.8695 - recall: 0.7076 - auc: 0.8683
# Epoch 00021: val_auc did not improve from 0.72965
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.1576 - accuracy: 0.9435 - precision: 0.8695 - recall: 0.7076 - auc: 0.8683 - val_loss: 0.3044 - val_accuracy: 0.9052 - val_precision: 0.7106 - val_recall: 0.5576 - val_auc: 0.7026
# Epoch 22/40
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.1561 - accuracy: 0.9441 - precision: 0.8704 - recall: 0.7110 - auc: 0.8704
# Epoch 00022: val_auc did not improve from 0.72965
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.1561 - accuracy: 0.9441 - precision: 0.8704 - recall: 0.7110 - auc: 0.8704 - val_loss: 0.2980 - val_accuracy: 0.9067 - val_precision: 0.7231 - val_recall: 0.5529 - val_auc: 0.6966
# Epoch 23/40
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.1545 - accuracy: 0.9445 - precision: 0.8710 - recall: 0.7143 - auc: 0.8726
# Epoch 00023: val_auc did not improve from 0.72965
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.1545 - accuracy: 0.9445 - precision: 0.8710 - recall: 0.7143 - auc: 0.8726 - val_loss: 0.3074 - val_accuracy: 0.9107 - val_precision: 0.7508 - val_recall: 0.5529 - val_auc: 0.6943
# Epoch 24/40
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.1532 - accuracy: 0.9447 - precision: 0.8705 - recall: 0.7163 - auc: 0.8742
# Epoch 00024: val_auc did not improve from 0.72965
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.1532 - accuracy: 0.9447 - precision: 0.8705 - recall: 0.7163 - auc: 0.8742 - val_loss: 0.3261 - val_accuracy: 0.9102 - val_precision: 0.7345 - val_recall: 0.5729 - val_auc: 0.7099
# Epoch 25/40
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.1519 - accuracy: 0.9451 - precision: 0.8713 - recall: 0.7190 - auc: 0.8760
# Epoch 00025: val_auc did not improve from 0.72965
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.1519 - accuracy: 0.9451 - precision: 0.8713 - recall: 0.7190 - auc: 0.8760 - val_loss: 0.3051 - val_accuracy: 0.8985 - val_precision: 0.6829 - val_recall: 0.5294 - val_auc: 0.6894
# Epoch 26/40
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.1507 - accuracy: 0.9455 - precision: 0.8714 - recall: 0.7220 - auc: 0.8776
# Epoch 00026: val_auc did not improve from 0.72965
# 1563/1563 [==============================] - 24s 16ms/step - loss: 0.1507 - accuracy: 0.9455 - precision: 0.8714 - recall: 0.7220 - auc: 0.8776 - val_loss: 0.2799 - val_accuracy: 0.9140 - val_precision: 0.7702 - val_recall: 0.5600 - val_auc: 0.7208
# Epoch 27/40
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.1497 - accuracy: 0.9458 - precision: 0.8716 - recall: 0.7237 - auc: 0.8789
# Epoch 00027: val_auc did not improve from 0.72965
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.1497 - accuracy: 0.9458 - precision: 0.8716 - recall: 0.7237 - auc: 0.8789 - val_loss: 0.2806 - val_accuracy: 0.9105 - val_precision: 0.7419 - val_recall: 0.5647 - val_auc: 0.7223
# Epoch 28/40
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.1484 - accuracy: 0.9462 - precision: 0.8723 - recall: 0.7267 - auc: 0.8806
# Epoch 00028: val_auc did not improve from 0.72965
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.1484 - accuracy: 0.9462 - precision: 0.8722 - recall: 0.7267 - auc: 0.8806 - val_loss: 0.3153 - val_accuracy: 0.9123 - val_precision: 0.7605 - val_recall: 0.5565 - val_auc: 0.6879
# Epoch 29/40
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.1474 - accuracy: 0.9465 - precision: 0.8727 - recall: 0.7284 - auc: 0.8820
# Epoch 00029: val_auc did not improve from 0.72965
# 1563/1563 [==============================] - 24s 16ms/step - loss: 0.1474 - accuracy: 0.9465 - precision: 0.8727 - recall: 0.7284 - auc: 0.8820 - val_loss: 0.3003 - val_accuracy: 0.9087 - val_precision: 0.7157 - val_recall: 0.5894 - val_auc: 0.7203
# Epoch 30/40
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.1462 - accuracy: 0.9467 - precision: 0.8721 - recall: 0.7306 - auc: 0.8835
# Epoch 00030: val_auc did not improve from 0.72965
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.1462 - accuracy: 0.9467 - precision: 0.8721 - recall: 0.7306 - auc: 0.8835 - val_loss: 0.2853 - val_accuracy: 0.9135 - val_precision: 0.7598 - val_recall: 0.5694 - val_auc: 0.7284
# Epoch 31/40
# 1561/1563 [============================>.] - ETA: 0s - loss: 0.1455 - accuracy: 0.9470 - precision: 0.8729 - recall: 0.7324 - auc: 0.8844
# Epoch 00031: val_auc improved from 0.72965 to 0.73131, saving model to checkpoints/my_ckpt
# 1563/1563 [==============================] - 25s 16ms/step - loss: 0.1455 - accuracy: 0.9470 - precision: 0.8729 - recall: 0.7324 - auc: 0.8844 - val_loss: 0.2952 - val_accuracy: 0.9178 - val_precision: 0.7802 - val_recall: 0.5847 - val_auc: 0.7313
# Epoch 32/40
# 1560/1563 [============================>.] - ETA: 0s - loss: 0.1448 - accuracy: 0.9471 - precision: 0.8727 - recall: 0.7338 - auc: 0.8853
# Epoch 00032: val_auc did not improve from 0.73131
# 1563/1563 [==============================] - 24s 16ms/step - loss: 0.1448 - accuracy: 0.9471 - precision: 0.8726 - recall: 0.7338 - auc: 0.8853 - val_loss: 0.3138 - val_accuracy: 0.9012 - val_precision: 0.6898 - val_recall: 0.5494 - val_auc: 0.6841
# Epoch 33/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1436 - accuracy: 0.9475 - precision: 0.8733 - recall: 0.7360 - auc: 0.8868
# Epoch 00033: val_auc did not improve from 0.73131
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.1436 - accuracy: 0.9475 - precision: 0.8733 - recall: 0.7360 - auc: 0.8868 - val_loss: 0.2942 - val_accuracy: 0.9113 - val_precision: 0.7373 - val_recall: 0.5812 - val_auc: 0.7134
# Epoch 34/40
# 1563/1563 [==============================] - ETA: 0s - loss: 0.1427 - accuracy: 0.9477 - precision: 0.8735 - recall: 0.7376 - auc: 0.8879
# Epoch 00034: val_auc did not improve from 0.73131
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.1427 - accuracy: 0.9477 - precision: 0.8735 - recall: 0.7376 - auc: 0.8879 - val_loss: 0.3050 - val_accuracy: 0.9077 - val_precision: 0.7229 - val_recall: 0.5647 - val_auc: 0.7116
# Epoch 35/40
# 1562/1563 [============================>.] - ETA: 0s - loss: 0.1415 - accuracy: 0.9481 - precision: 0.8741 - recall: 0.7400 - auc: 0.8895
# Epoch 00035: val_auc did not improve from 0.73131
# 1563/1563 [==============================] - 24s 15ms/step - loss: 0.1415 - accuracy: 0.9481 - precision: 0.8741 - recall: 0.7400 - auc: 0.8895 - val_loss: 0.3423 - val_accuracy: 0.9035 - val_precision: 0.6944 - val_recall: 0.5694 - val_auc: 0.6922
# Epoch 36/40
#  641/1563 [===========>..................] - ETA: 13s - loss: 0.1372 - accuracy: 0.9496 - precision: 0.8772 - recall: 0.7490 - auc: 0.8952
