# %% [markdown]
# ### Open this notebook from google drive
# Go to "Edit" -> "Notebook settings" and enable **GPU**

# %%
# !nvidia-smi
# Out:
# Tue Aug 25 13:19:55 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.57       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   72C    P8    79W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
#  **Connect and authorize google drive with google colab**

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
pwd
# Out:
# '/content'

# %% [markdown]
# **go to our project direcotry in google drive:**

# %%
# %cd gdrive/My\ Drive/spectrum_detector_v1
# !ls
# Out:
# /content/gdrive/My Drive/spectrum_detector_v1
# batch_detector.ipynb  detector_train.ipynb   mat	   saved_models2
# batch_train.ipynb     DL_trainset	     mat2	   saved_models3
# checkpoints	      EEG		     mat3	   train_subj.py
# detector.ipynb	      generate_images_v2.py  __pycache__   utils.py
# detector_subj.py      logs		     saved_models

# %% [markdown]
# # Start my python code here

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
print ('tf:', tf.__version__)
import time
from numpy import save, load
from generate_images_v2 import prepare_one_dataset, plotbars, xloc2binaryvec

# sklearn for PR and ROC curves
from sklearn.metrics import precision_recall_curve, average_precision_score
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.metrics import roc_curve, auc, RocCurveDisplay
from utils import normalize_matrix_1, plot1bar
from utils import plot_loss, plot_metrics, shuffle_trainset
from scipy.io import loadmat, savemat
# Out:
# tf: 2.3.0

# %%
#%% load saved data (.mat) from MATLAB
subj = 's21'
# (1)train set:
filename1 = 'DL_trainset/AVG_ram100/' + subj + '.mat'
file = loadmat(filename1)
data1 = file['SNR3D_arr']
 
# (2) dev set:
AVG_spectrum_s1 = 'DL_trainset/AVG96/' + subj + '.mat'
file = loadmat(AVG_spectrum_s1)
data1_dev = file['SNR3D']
print('data1_dev:', data1_dev.shape)

# check shape of INPUT data
r, c = data1.shape
for i in range(c):
    print(data1[0,i].shape)
# Out:
# data1_dev: (96, 60, 120)
# (100, 60, 120)
# (100, 60, 120)
# (100, 60, 120)
# (100, 60, 120)
# (100, 60, 120)

# %%
#%% orginal labels -> binary labels
labels_full= [4, 6, 27, 33, 35, 37, 39, 43, 45, 66, 72, 76, 78, 99,105,111,117]
labels_subset = [6, 33, 37, 39, 43, 66, 72, 78, 99, 117] # (1)
labels_subset2= [6, 33, 37, 39, 43, 45, 66, 72, 76, 78, 99, 117] # (2)
labels_subset3= [6, 33, 35, 37, 39, 43, 45, 66, 72, 76, 78, 99, 117] # (3)

# choose one annotation from above !
labels_2use = labels_subset

# %%
labels_org = np.array(labels_2use)-1 # python starts from 0
labels_bi = xloc2binaryvec(labels_org) # binary code label: 1 and 0  

# plot first num sample of train set
num = 5 # ntrials = [50, 60, 70, 80, 90]
plt.figure(figsize=(16, 16))
for i in range(num):
    # plot the sample
    images_num = data1[0,i][0]
    plt.subplot(num,1,i+1)
    plt.imshow(images_num, cmap='gray')
    plot1bar(labels_org)
    plt.title('Number of AVG trials:{}'.format((i+5)*10))

# %%
#%% prepare {x_train, y_train, x_test, y_test}
# option B: use AVG- [50, 60, 70, 80, 90] trials for train
x_train = np.concatenate((data1[0,0],data1[0,1],data1[0,2],data1[0,3],data1[0,4]), axis=0)
# dev set (1):
# x_test_100tr = data1_dev[-1] # AVG 100 trials
# x_test = np.reshape(x_test_100tr, (1, x_test_100tr.shape[0], x_test_100tr.shape[1]))
# dev set (2):
x_test = data1_dev # (96, 60, 120)
# dev set (3):
# x_test = data1_dev[-50:,:,:] # (50, 60, 120)

print('dev_set: ',x_test.shape)

# normalize X to [0 - 1] 
x_train = normalize_matrix_1(x_train)
x_test =  normalize_matrix_1(x_test)

# repeating Y (labels_bi) the number of times given by number of samples  
y_train = np.tile(labels_bi, (len(x_train),1))# (10k,120)
y_test  = np.tile(labels_bi, (len(x_test),1))# (100,120)

# shuffle [x_train, y_train] 100x along the dimenstion of frequency '1-120' 
x_train, y_train = shuffle_trainset(x_train, y_train)
# Out:
# dev_set:  (96, 60, 120)

# %%
#%% check shuffled labels: plot m samples with shuffled labels
m = 5
n_start = 100
fig = plt.figure(figsize=(16, 16))
for i in range(m):
    image = x_train[n_start+i]
    label = np.where(y_train[n_start+i] > 0.5)[0] # len() == 6 
    plt.subplot(m,1,i+1)
    plt.imshow(image, cmap='gray')
    if i==0:
        plt.title('check shuffled labels')
    plot1bar(label)

# %%
#%% define a model
tf.keras.backend.clear_session()
def create_model():
    # (C) CNN model (~2 conv layers): ~ 230k paras
    inputs = keras.Input(shape=(60, 120, 1)) # 1 is needed here to keep the same dim with next conv2D layer
    x = layers.experimental.preprocessing.Rescaling(1.0 / 1)(inputs)
    x = layers.Conv2D(filters=8, kernel_size=(3, 3), padding='same', activation="relu")(x)
    x = layers.MaxPooling2D(pool_size=(3, 3), strides=(1, 1),padding='same')(x) # stride =1, not =3 be default
    x = layers.Dropout(.2)(x)
    x = layers.Conv2D(filters=4, kernel_size=(3, 3), padding='same', activation="relu")(x)
    x = layers.MaxPooling2D(pool_size=(2, 2), strides=(1, 1), padding='same')(x) # stride =1, not =2 be default
    x = layers.Dropout(.2)(x)
    x = layers.Flatten()(x)
    x = layers.Dense(1024, activation="relu")(x) # it does not further improve!
    outputs = layers.Dense(120, activation= 'sigmoid')(x)
    model = keras.Model(inputs, outputs)

    loss = tf.keras.losses.BinaryCrossentropy()
    # optimizer = tf.keras.optimizers.SGD(learning_rate=0.01)
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.001, 
                                         beta_1=0.9, beta_2=0.999, epsilon=1e-07)
    
    # METRICS = [
    #       keras.metrics.TruePositives(name='tp'),
    #       keras.metrics.FalsePositives(name='fp'),
    #       keras.metrics.TrueNegatives(name='tn'),
    #       keras.metrics.FalseNegatives(name='fn'), 
    #       keras.metrics.BinaryAccuracy(name='accuracy'),
    #       keras.metrics.Precision(name='precision'),
    #       keras.metrics.Recall(name='recall'),
    #       keras.metrics.AUC(name='auc'),
    #       ]
    
    METRICS = [ 
          keras.metrics.BinaryAccuracy(name='accuracy'),
          keras.metrics.Precision(name='precision'),
          keras.metrics.Recall(name='recall'),
          keras.metrics.AUC(name='auc', curve='PR'), # curve='ROC' by default
          ]
    
    model.compile(
        optimizer= optimizer,
        loss=loss,
        metrics= METRICS,
        )
    
    return model

# %%
#%% Build a model
# Create a basic model instance
model = create_model() 
# show model
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 60, 120, 1)]      0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 60, 120, 1)        0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 60, 120, 8)        80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 60, 120, 8)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 60, 120, 8)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 60, 120, 4)        292
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 60, 120, 4)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 60, 120, 4)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 28800)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              29492224
# _________________________________________________________________
# dense_1 (Dense)              (None, 120)               123000
# =================================================================
# Total params: 29,615,596
# Trainable params: 29,615,596
# Non-trainable params: 0
# _________________________________________________________________

# %%
#%% train
N_epoch = 40
# (callback 1) for using TensorBoard
callback_log = [keras.callbacks.TensorBoard(log_dir='./logs')] 
# Launch TensorBoard from the command line (1st cd: folder of this proj) 
# in cmd type: tensorboard --logdir logs

# (callback 2) Create a callback that saves the model's weights
# only model that achieves larger 'val_auc' is saved.
checkpoint_path = "checkpoints/my_ckpt"
callback_cp = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 monitor='val_auc',
                                                 mode='max',
                                                 save_best_only=True,
                                                 verbose=1)
start_time = time.time()
# Train the model from Numpy data input
history = model.fit(x_train, y_train, 
                    validation_data= (x_test, y_test), 
                    batch_size= 256, 
                    epochs=N_epoch, 
                    callbacks=[callback_log, callback_cp])

print('elapsed_time:',  time.time() - start_time) # =203 s for 100 epochs

#%% plot learning curves - [loss, AUC, etc.]
plt.figure(figsize=(12, 10)) 
plot_loss(history, "loss", 2)
# plot metrics over epochs
plt.figure(figsize=(12, 10))    
plot_metrics(history)
# Out:
# Epoch 1/40
#   1/196 [..............................] - ETA: 0s - loss: 0.6990 - accuracy: 0.4925 - precision: 0.0849 - recall: 0.5207 - auc: 0.0850WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#   2/196 [..............................] - ETA: 22s - loss: 0.5693 - accuracy: 0.6978 - precision: 0.0850 - recall: 0.2689 - auc: 0.0841WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0713s vs `on_train_batch_end` time: 0.1596s). Check your callbacks.
# 196/196 [==============================] - ETA: 0s - loss: 0.2907 - accuracy: 0.9144 - precision: 0.0851 - recall: 0.0028 - auc: 0.0995
# Epoch 00001: val_auc improved from -inf to 0.20492, saving model to checkpoints/my_ckpt
# 196/196 [==============================] - 31s 160ms/step - loss: 0.2907 - accuracy: 0.9144 - precision: 0.0851 - recall: 0.0028 - auc: 0.0995 - val_loss: 0.5523 - val_accuracy: 0.9079 - val_precision: 0.3528 - val_recall: 0.1260 - val_auc: 0.2049
# Epoch 2/40
# 196/196 [==============================] - ETA: 0s - loss: 0.2028 - accuracy: 0.9373 - precision: 0.8451 - recall: 0.3028 - auc: 0.5380
# Epoch 00002: val_auc improved from 0.20492 to 0.64119, saving model to checkpoints/my_ckpt
# 196/196 [==============================] - 30s 153ms/step - loss: 0.2028 - accuracy: 0.9373 - precision: 0.8451 - recall: 0.3028 - auc: 0.5380 - val_loss: 0.2154 - val_accuracy: 0.9589 - val_precision: 0.9092 - val_recall: 0.5635 - val_auc: 0.6412
# Epoch 3/40
# 196/196 [==============================] - ETA: 0s - loss: 0.1531 - accuracy: 0.9529 - precision: 0.9373 - recall: 0.4661 - auc: 0.7219
# Epoch 00003: val_auc improved from 0.64119 to 0.72325, saving model to checkpoints/my_ckpt
# 196/196 [==============================] - 30s 155ms/step - loss: 0.1531 - accuracy: 0.9529 - precision: 0.9373 - recall: 0.4661 - auc: 0.7219 - val_loss: 0.1495 - val_accuracy: 0.9632 - val_precision: 0.9337 - val_recall: 0.6010 - val_auc: 0.7233
# Epoch 4/40
# 196/196 [==============================] - ETA: 0s - loss: 0.1290 - accuracy: 0.9597 - precision: 0.9051 - recall: 0.5775 - auc: 0.7879
# Epoch 00004: val_auc improved from 0.72325 to 0.73240, saving model to checkpoints/my_ckpt
40
# 196/196 [==============================] - ETA: 0s - loss: 0.0903 - accuracy: 0.9703 - precision: 0.9016 - recall: 0.7223 - auc: 0.8782
# Epoch 00011: val_auc did not improve from 0.80347
# 196/196 [==============================] - 29s 146ms/step - loss: 0.0903 - accuracy: 0.9703 - precision: 0.9016 - recall: 0.7223 - auc: 0.8782 - val_loss: 0.1214 - val_accuracy: 0.9632 - val_precision: 0.9351 - val_recall: 0.6000 - val_auc: 0.7949
# Epoch 12/40
# 196/196 [==============================] - ETA: 0s - loss: 0.0875 - accuracy: 0.9711 - precision: 0.9031 - recall: 0.7316 - auc: 0.8843
# Epoch 00012: val_auc did not improve from 0.80347
# 196/196 [==============================] - 29s 146ms/step - loss: 0.0875 - accuracy: 0.9711 - precision: 0.9031 - recall: 0.7316 - auc: 0.8843 - val_loss: 0.1319 - val_accuracy: 0.9630 - val_precision: 0.9133 - val_recall: 0.6146 - val_auc: 0.7712
# Epoch 13/40
# 196/196 [==============================] - ETA: 0s - loss: 0.0846 - accuracy: 0.9719 - precision: 0.9051 - recall: 0.7405 - auc: 0.8905
# Epoch 00013: val_auc improved from 0.80347 to 0.80814, saving model to checkpoints/my_ckpt
# 196/196 [==============================] - 30s 155ms/step - loss: 0.0846 - accuracy: 0.9719 - precision: 0.9051 - recall: 0.7405 - auc: 0.8905 - val_loss: 0.1159 - val_accuracy: 0.9671 - val_precision: 0.9132 - val_recall: 0.6687 - val_auc: 0.8081
# Epoch 14/40
# 196/196 [==============================] - ETA: 0s - loss: 0.0820 - accuracy: 0.9726 - precision: 0.9065 - recall: 0.7478 - auc: 0.8958
# Epoch 00014: val_auc did not improve from 0.80814
# 196/196 [==============================] - 29s 146ms/step - loss: 0.0820 - accuracy: 0.9726 - precision: 0.9065 - recall: 0.7478 - auc: 0.8958 - val_loss: 0.1176 - val_accuracy: 0.9689 - val_precision: 0.9375 - val_recall: 0.6719 - val_auc: 0.8078
# Epoch 15/40
# 196/196 [==============================] - ETA: 0s - loss: 0.0795 - accuracy: 0.9733 - precision: 0.9083 - recall: 0.7559 - auc: 0.9009
# Epoch 00015: val_auc did not improve from 0.80814
# 196/196 [==============================] - 29s 146ms/step - loss: 0.0795 - accuracy: 0.9733 - precision: 0.9083 - recall: 0.7559 - auc: 0.9009 - val_loss: 0.1251 - val_accuracy: 0.9656 - val_precision: 0.9123 - val_recall: 0.6500 - val_auc: 0.7967
# Epoch 16/40
# 196/196 [==============================] - ETA: 0s - loss: 0.0770 - accuracy: 0.9739 - precision: 0.9096 - recall: 0.7632 - auc: 0.9059
# Epoch 00016: val_auc improved from 0.80814 to 0.84764, saving model to checkpoints/my_ckpt
# 196/196 [==============================] - 30s 154ms/step - loss: 0.0770 - accuracy: 0.9739 - precision: 0.9096 - recall: 0.7632 - auc: 0.9059 - val_loss: 0.1018 - val_accuracy: 0.9701 - val_precision: 0.9253 - val_recall: 0.6969 - val_auc: 0.8476
# Epoch 17/40
# 196/196 [==============================] - ETA: 0s - loss: 0.0749 - accuracy: 0.9746 - precision: 0.9115 - recall: 0.7697 - auc: 0.9102
# Epoch 00017: val_auc did not improve from 0.84764
# 196/196 [==============================] - 29s 146ms/step - loss: 0.0749 - accuracy: 0.9746 - precision: 0.9115 - recall: 0.7697 - auc: 0.9102 - val_loss: 0.1199 - val_accuracy: 0.9648 - val_precision: 0.8935 - val_recall: 0.6552 - val_auc: 0.8140
# Epoch 18/40
# 196/196 [==============================] - ETA: 0s - loss: 0.
40
# 196/196 [==============================] - ETA: 0s - loss: 0.0606 - accuracy: 0.9786 - precision: 0.9190 - recall: 0.8148 - auc: 0.9369
# Epoch 00026: val_auc did not improve from 0.84764
# 196/196 [==============================] - 28s 145ms/step - loss: 0.0606 - accuracy: 0.9786 - precision: 0.9190 - recall: 0.8148 - auc: 0.9369 - val_loss: 0.1260 - val_accuracy: 0.9641 - val_precision: 0.8711 - val_recall: 0.6687 - val_auc: 0.8047
# Epoch 27/40
# 196/196 [==============================] - ETA: 0s - loss: 0.0597 - accuracy: 0.9789 - precision: 0.9198 - recall: 0.8177 - auc: 0.9385
# Epoch 00027: val_auc did not improve from 0.84764
# 196/196 [==============================] - 28s 145ms/step - loss: 0.0597 - accuracy: 0.9789 - precision: 0.9198 - recall: 0.8177 - auc: 0.9385 - val_loss: 0.1215 - val_accuracy: 0.9669 - val_precision: 0.8834 - val_recall: 0.6948 - val_auc: 0.8188
# Epoch 28/40
# 196/196 [==============================] - ETA: 0s - loss: 0.0581 - accuracy: 0.9793 - precision: 0.9210 - recall: 0.8225 - auc: 0.9412
# Epoch 00028: val_auc did not improve from 0.84764
# 196/196 [==============================] - 28s 145ms/step - loss: 0.0581 - accuracy: 0.9793 - precision: 0.9210 - recall: 0.8225 - auc: 0.9412 - val_loss: 0.1294 - val_accuracy: 0.9664 - val_precision: 0.8785 - val_recall: 0.6927 - val_auc: 0.8088
# Epoch 29/40
# 196/196 [==============================] - ETA: 0s - loss: 0.0570 - accuracy: 0.9797 - precision: 0.9214 - recall: 0.8267 - auc: 0.9431
# Epoch 00029: val_auc did not improve from 0.84764
# 196/196 [==============================] - 28s 145ms/step - loss: 0.0570 - accuracy: 0.9797 - precision: 0.9214 - recall: 0.8267 - auc: 0.9431 - val_loss: 0.1295 - val_accuracy: 0.9662 - val_precision: 0.8742 - val_recall: 0.6948 - val_auc: 0.8114
# Epoch 30/40
# 196/196 [==============================] - ETA: 0s - loss: 0.0560 - accuracy: 0.9799 - precision: 0.9216 - recall: 0.8290 - auc: 0.9447
# Epoch 00030: val_auc did not improve from 0.84764
# 196/196 [==============================] - 28s 145ms/step - loss: 0.0560 - accuracy: 0.9799 - precision: 0.9216 - recall: 0.8290 - auc: 0.9447 - val_loss: 0.1240 - val_accuracy: 0.9670 - val_precision: 0.8836 - val_recall: 0.6958 - val_auc: 0.8218
# Epoch 31/40
# 196/196 [==============================] - ETA: 0s - loss: 0.0550 - accuracy: 0.9802 - precision: 0.9227 - recall: 0.8327 - auc: 0.9465
# Epoch 00031: val_auc did not improve from 0.84764
# 196/196 [==============================] - 28s 145ms/step - loss: 0.0550 - accuracy: 0.9802 - precision: 0.9227 - recall: 0.8327 - auc: 0.9465 - val_loss: 0.1350 - val_accuracy: 0.9633 - val_precision: 0.8575 - val_recall: 0.6708 - val_auc: 0.8007
# Epoch 32/40
# 196/196 [==============================] - ETA: 0s - loss: 0.0539 - accuracy: 0.9806 - precision: 0.9237 - recall: 0.8362 - auc: 0.9483
# Epoch 00032: val_auc did not improve from 0.84764
# 196/196 [==============================] - 29s 146ms/step - loss: 0.0539 - accuracy: 0.9806 - precision: 0.9237 - recall: 0.8362 - auc: 0.9483 - val_loss: 0.1351 - val_accuracy: 0.9661 - val_precision: 0.8800 - val_recall: 0.6875 - val_auc: 0.8044
# Epoch 33/40
# 196/196 [==============================] - ETA: 0s - loss: 0.0530 - accuracy: 0.9808 - precision: 0.9241 - recall: 0.8388 - auc: 0.9498
# Epoch 00033: val_auc did not improve from 0.84764
# 196/196 [==============================] - 28s 145ms/step - loss: 0.0530 - accuracy: 0.9808 - precision: 0.9241 - recall: 0.8388 - auc: 0.9498 - val_loss: 0.1311 - val_accuracy: 0.9620 - val_precision: 0.8452 - val_recall: 0.6656 - val_auc: 0.7966
# Epoch 34/40
# 196/196 [==============================] - ETA: 0s - loss: 0.0520 - accuracy: 0.9811 - precision: 0.9245 - recall: 0.8418 - auc: 0.9515
# Epoch 00034: val_auc did not improve from 0.84764
# 196/196 [==============================] - 28s 145ms/step - loss: 0.0520 - accuracy: 0.9811 - precision: 0.9245 - recall: 0.8418 - auc: 0.9515 - val_loss: 0.1400 - val_accuracy: 0.9617 - val_precision: 0.8531 - val_recall: 0.6531 - val_auc: 0.7901
# Epoch 35/40
# 196/196 [==============================] - ETA: 0s - loss: 0.0511 - accuracy: 0.9814 - precision: 0.9255 - recall: 0.8451 - auc: 0.9529
# Epoch 00035: val_auc did not improve from 0.84764
# 196/196 [==============================] - 28s 145ms/step - loss: 0.0511 - accuracy: 0.9814 - precision: 0.9255 - recall: 0.8451 - auc: 0.9529 - val_loss: 0.1604 - val_accuracy: 0.9597 - val_precision: 0.8204 - val_recall: 0.6615 - val_auc: 0.7630
# Epoch 36/40
# 196/196 [==============================] - ETA: 0s - loss: 0.0503 - accuracy: 0.9817 - precision: 0.9257 - recall: 0.8482 - auc: 0.9540
# Epoch 00036: val_auc did not improve from 0.84764
# 196/196 [==============================] - 28s 145ms/step - loss: 0.0503 - accuracy: 0.9817 - precision: 0.9257 - recall: 0.8482 - auc: 0.9540 - val_loss: 0.1298 - val_accuracy: 0.9630 - val_precision: 0.8688 - val_recall: 0.6552 - val_auc: 0.8062
# Epoch 37/40
# 196/196 [==============================] - ETA: 0s - loss: 0.0496 - accuracy: 0.9819 - precision: 0.9263 - recall: 0.8501 - auc: 0.9552
# Epoch 00037: val_auc did not improve from 0.84764
# 196/196 [==============================] - 28s 145ms/step - loss: 0.0496 - accuracy: 0.9819 - precision: 0.9263 - recall: 0.8501 - auc: 0.9552 - val_loss: 0.1286 - val_accuracy: 0.9650 - val_precision: 0.8486 - val_recall: 0.7063 - val_auc: 0.8151
# Epoch 38/40
# 196/196 [==============================] - ETA: 0s - loss: 0.0487 - accuracy: 0.9822 - precision: 0.9274 - recall: 0.8528 - auc: 0.9566
# Epoch 00038: val_auc did not improve from 0.84764
# 196/196 [==============================] - 29s 145ms/step - loss: 0.0487 - accuracy: 0.9822 - precision: 0.9274 - recall: 0.8528 - auc: 0.9566 - val_loss: 0.1330 - val_accuracy: 0.9667 - val_precision: 0.8830 - val_recall: 0.6917 - val_auc: 0.8139
# Epoch 39/40
# 196/196 [==============================] - ETA: 0s - loss: 0.0481 - accuracy: 0.9823 - precision: 0.9274 - recall: 0.8546 - auc: 0.9575
# Epoch 00039: val_auc did not improve from 0.84764
# 196/196 [==============================] - 29s 146ms/step - loss: 0.0481 - accuracy: 0.9823 - precision: 0.9274 - recall: 0.8546 - auc: 0.9575 - val_loss: 0.1211 - val_accuracy: 0.9669 - val_precision: 0.8907 - val_recall: 0.6875 - val_auc: 0.8231
# Epoch 40/40
# 196/196 [==============================] - ETA: 0s - loss: 0.0473 - accuracy: 0.9826 - precision: 0.9282 - recall: 0.8574 - auc: 0.9588
# Epoch 00040: val_auc did not improve from 0.84764
# 196/196 [==============================] - 28s 145ms/step - loss: 0.0473 - accuracy: 0.9826 - precision: 0.9282 - recall: 0.8574 - auc: 0.9588 - val_loss: 0.1346 - val_accuracy: 0.9623 - val_precision: 0.8535 - val_recall: 0.6615 - val_auc: 0.7959
# elapsed_time: 1166.2553670406342

# %%
#%% test the latest trained_model on the dev set: x_test
predictions = model.predict(x_test)
predictions_mean = np.mean(predictions, axis = 0)

labels2plt = labels_org

plt.figure(figsize=(16, 9))
plt.imshow(predictions, cmap='gray')
plot1bar(labels2plt, L=96)
plt.xlabel('frequency')
plt.ylabel('All test samples')
plt.title('prediction on AVG 90 trials (with Ann)')

plt.figure(figsize=(16, 9))
plt.plot(predictions_mean)
plot1bar(labels2plt, L=2)
plt.grid(True)
plt.xlabel('frequency')
plt.ylabel('probability of ASSR')
plt.title('Mean prediction')
# Out:
# Text(0.5, 1.0, 'Mean prediction')

# %% [markdown]
# ## Save the best trained model

# %% [markdown]
# **Evaluate the saved 'best model weights' from callback_func**

# %%
# Create a basic model instance
model = create_model() 
# Display the model's architecture
model.summary()
# Evaluate the initial model
loss, acc,_,_,_ = model.evaluate(x_test, y_test, verbose=2)
print("Untrained model, accuracy: {:5.2f}%".format(100*acc))

# Re-load the model weights from the saved checkpoints
model.load_weights(checkpoint_path) # Loads the weights
# Evaluate the saved model
loss, acc,_,_,_ = model.evaluate(x_test, y_test, verbose=2)
print("saved model, accuracy: {:5.2f}%".format(100*acc))


#%% save the entire trained model (not only weights in checkpoints)
# choose the path for saving 
save_dir = os.path.join(os.getcwd(), 'saved_models3')
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
    
model_name = subj +'_best_trained_model.h5'
model_path = os.path.join(save_dir, model_name)  
model.save(model_path)
print('Saved trained model at %s ' % model_path)
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 60, 120, 1)]      0
# _________________________________________________________________
# rescaling_1 (Rescaling)      (None, 60, 120, 1)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 60, 120, 8)        80
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 60, 120, 8)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 60, 120, 8)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 60, 120, 4)        292
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 60, 120, 4)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 60, 120, 4)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 28800)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              29492224
# _________________________________________________________________
# dense_3 (Dense)              (None, 120)               123000
# =================================================================
# Total params: 29,615,596
# Trainable params: 29,615,596
# Non-trainable params: 0
# _________________________________________________________________
# 3/3 - 0s - loss: 0.6818 - accuracy: 0.5984 - precision: 0.1125 - recall: 0.5542 - auc: 0.1141
# Untrained model, accuracy: 59.84%
# 3/3 - 0s - loss: 0.1018 - accuracy: 0.9701 - precision: 0.9253 - recall: 0.6969 - auc: 0.8476
# saved model, accuracy: 97.01%
# Saved trained model at /content/gdrive/My Drive/spectrum_detector_v1/saved_models3/s21_best_trained_model.h5

# %%
#%% test the best_trained_model on the dev set: x_test
predictions = model.predict(x_test)
predictions_mean = np.mean(predictions, axis = 0)

labels2plt = labels_org

plt.figure(figsize=(16, 9))
plt.imshow(predictions, cmap='gray')
plot1bar(labels2plt, L=96)
plt.xlabel('frequency')
plt.ylabel('All test samples')
plt.title('prediction on AVG 90 trials (with Ann)')

plt.figure(figsize=(16, 9))
plt.plot(predictions_mean)
plot1bar(labels2plt, L=2)
plt.grid(True)
plt.xlabel('frequency')
plt.ylabel('probability of ASSR')
plt.title('Mean prediction')
# Out:
# Text(0.5, 1.0, 'Mean prediction')
