# %% [markdown]
# # Open this notebook from google drive
# Go to "Edit" -> "Notebook settings" and enable GPU

# %%
# !nvidia-smi
# Out:
# Tue Aug 25 18:33:28 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.57       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# %cd gdrive/My\ Drive/spectrum_detector_v1
# !ls
# Out:
# /content/gdrive/My Drive/spectrum_detector_v1
# batch_detector.ipynb  EEG		     saved_models
# batch_train.ipynb     generate_images_v2.py  saved_models2
# checkpoints	      logs		     saved_models3
# detector.ipynb	      mat		     saved_models_40epochs
# detector_subj.py      mat2		     saved_models_fullASSR
# detector_train.ipynb  mat3		     train_subj.py
# DL_trainset	      __pycache__	     utils.py

# %% [markdown]
# # Start my python code here

# %%
import os
import time
from detector_subj import detector_subj

# %%
# choose the path for saving 
save_dir = os.path.join(os.getcwd(), 'mat3')
if not os.path.isdir(save_dir):
  os.makedirs(save_dir)

print(save_dir)
# Out:
# /content/gdrive/My Drive/spectrum_detector_v1/mat3

# %%
day_1 = ['s21', 's22', 's24', 's25', 's28', 's30', 's31', 's33', 's34', 's38'] # day 1
day_2 = ['s23', 's27', 's26', 's29', 's37', 's36', 's32', 's35', 's39', 's40'] # day 2

# %%
subj_train = day_1[0]
subj_test = day_2[0]
print(subj_train)
print(subj_test)
# Out:
# s21
# s23

# %%
model_dir = os.path.join(os.getcwd(), 'saved_models_fullASSR')
detector_subj (subj_train, subj_test, model_dir, save_dir)
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
# batch processing on 10 subjects:
for i, _ in enumerate(day_1):
    subj_train = day_1[i]
    subj_test  = day_2[i]
    detector_subj (subj_train, subj_test, model_dir, save_dir)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
